# %% [markdown]
# <a href="https://colab.research.google.com/github/swarna-malapolu/UNP-Assignments/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
import datetime

# %%
data = pd.read_excel("Housing.xlsx",index_col=0)
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice  Acre  LandValue  BuildingValue  TotalValue  \
# UniqueID
# 2045      2013-04-09     240000   2.3    50000.0       168200.0    235700.0
# 16918     2014-06-10     366000   3.5    50000.0       264100.0    319000.0
# 54582     2016-09-26     435000   2.9    50000.0       216200.0    298000.0
# 43070     2016-01-29     255000   2.6    50000.0       147300.0    197300.0
# 22714     2014-10-10     278000   2.0    50000.0       152300.0    202300.0
# ...              ...        ...   ...        ...            ...         ...
# 30469     2015-05-27     157500   NaN        NaN            NaN         NaN
# 27707     2015-03-02     145000   NaN        NaN            NaN         NaN
# 52709     2016-08-16     234611   NaN        NaN            NaN         NaN
# 54042     2016-09-07      93844   NaN        NaN            NaN         NaN
# 54043     2016-09-07      93844   NaN        NaN            NaN         NaN
#
#            YearBuilt  Bedrooms  FullBath  HalfBath
# UniqueID
# 2045          1986.0       3.0       3.0       0.0
# 16918         1998.0       3.0       3.0       2.0
# 54582         1987.0       4.0       3.0       0.0
# 43070         1985.0       3.0       3.0       0.0
# 22714         1984.0       4.0       3.0       0.0
# ...              ...       ...       ...       ...
# 30469            NaN       NaN       NaN       NaN
# 27707            NaN       NaN       NaN       NaN
# 52709            NaN       NaN       NaN       NaN
# 54042            NaN       NaN       NaN       NaN
# 54043            NaN       NaN       NaN       NaN
#
# [56477 rows x 12 columns]

# %% [markdown]
# CLEANING DATA

# %% [markdown]
# 1. Replace the missing values with appropriate approximations

# %%
data['Acre']=data["Acre"].fillna(np.mean(data["Acre"]))
data['LandValue']=data["LandValue"].fillna(np.mean(data["LandValue"]))
data['BuildingValue']=data["BuildingValue"].fillna(np.mean(data["BuildingValue"]))
data['TotalValue']=data["TotalValue"].fillna(np.mean(data["TotalValue"]))
data['YearBuilt']=data["YearBuilt"].fillna(np.mean(data["YearBuilt"]))
data['Bedrooms']=data["Bedrooms"].fillna(np.mean(data["Bedrooms"]))
data['FullBath']=data["FullBath"].fillna(np.mean(data["FullBath"]))
data['HalfBath']=data["HalfBath"].fillna(np.mean(data["HalfBath"]))
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Acre     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullBath  HalfBath
# UniqueID
# 2045       235700.000000  1986.000000  3.000000  3.000000  0.000000
# 16918      319000.000000  1998.000000  3.000000  3.000000  2.000000
# 54582      298000.000000  1987.000000  4.000000  3.000000  0.000000
# 43070      197300.000000  1985.000000  3.000000  3.000000  0.000000
# 22714      202300.000000  1984.000000  4.000000  3.000000  0.000000
# ...                  ...          ...       ...       ...       ...
# 30469      232375.398847  1963.744899  3.089912  1.886014  0.283921
# 27707      232375.398847  1963.744899  3.089912  1.886014  0.283921
# 52709      232375.398847  1963.744899  3.089912  1.886014  0.283921
# 54042      232375.398847  1963.744899  3.089912  1.886014  0.283921
# 54043      232375.398847  1963.744899  3.089912  1.886014  0.283921
#
# [56477 rows x 12 columns]

# %% [markdown]
# 2. Rename the columns to better suited names

# %%
data.rename(columns={"FullBath":"FullWashroom"},inplace=True)
data.rename(columns={"HalfBath":"HalfWashroom"},inplace=True)
data.rename(columns={"Acre":"Area"},inplace=True)
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Area     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullWashroom  HalfWashroom
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
# [56477 rows x 12 columns]

# %% [markdown]
# 3. Extract the month and year from the sale date.

# %%
data['Year']=pd.DatetimeIndex(data['SaleDate']).year
data['Month']=pd.DatetimeIndex(data['SaleDate']).month
data['Day']=pd.DatetimeIndex(data['SaleDate']).day
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Area     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullWashroom  HalfWashroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day
# UniqueID
# 2045       2013      4    9
# 16918      2014      6   10
# 54582      2016      9   26
# 43070      2016      1   29
# 22714      2014     10   10
# ...         ...    ...  ...
# 30469      2015      5   27
# 27707      2015      3    2
# 52709      2016      8   16
# 54042      2016      9    7
# 54043      2016      9    7
#
# [56477 rows x 15 columns]

# %% [markdown]
# 4. Extract the pin number from the property address

# %% [markdown]
# 1. How has the price of properties changed over the years

# %%
a = data.groupby('Year')['SalePrice'].count()
a
# Out:
# Year
# 2013    11292
# 2014    14283
# 2015    16829
# 2016    14071
# 2019        2
# Name: SalePrice, dtype: int64

# %%
sns.barplot(x=a.index, y=a.values)

# %% [markdown]
# 2. Does a specific month or span of months have the highest property prices?

# %%
b=data.groupby('Month')['SalePrice'].count()
b
# Out:
# Month
# 1     3227
# 2     2778
# 3     4474
# 4     5223
# 5     5932
# 6     6593
# 7     5471
# 8     5620
# 9     5451
# 10    4822
# 11    3114
# 12    3772
# Name: SalePrice, dtype: int64

# %%
sns.barplot(x=b.index, y=b.values)

# %% [markdown]
# We can observe that June has the highest property prices, followed by July.

# %%
plt.pie(b,labels=b.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f2f9bc43550>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc43990>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc520d0>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc52710>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc62090>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc62750>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc62b50>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc731d0>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc52d50>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc737d0>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc43510>,
#   <matplotlib.patches.Wedge at 0x7f2f9bc7e990>],
#  [Text(1.0823253561428419, 0.1963971065221455, '1'),
#   Text(0.9581121237361517, 0.5403898207311101, '2'),
#   Text(0.669077134915978, 0.8731184269803418, '3'),
#   Text(0.12562097733416022, 1.0928034452972823, '4'),
#   Text(-0.533206442193423, 0.9621283126503617, '5'),
#   Text(-1.0263448877584371, 0.39574761069666753, '6'),
#   Text(-1.0498735320672372, -0.3282766617727549, '7'),
#   Text(-0.6664027529579892, -0.8751613398968291, '8'),
#   Text(-0.03844919297486516, -1.099327821698142, '9'),
#   Text(0.5622302755485646, -0.9454613250982746, '10'),
#   Text(0.9122792080051296, -0.6146109717874662, '11'),
#   Text(1.0758749374096637, -0.2291137688000277, '12')])

# %% [markdown]
# We can interpret that the mid year months have high property prices compared to the beginning and ending months

# %% [markdown]
# 3. For what purpose were the properties generally purchased?

# %%
c=data.groupby('LandUse')['SalePrice'].count()
c
# Out:
# LandUse
# APARTMENT: LOW RISE (BUILT SINCE 1960)            2
# CHURCH                                           34
# CLUB/UNION HALL/LODGE                             1
# CONDO                                           247
# CONDOMINIUM OFC  OR OTHER COM CONDO              35
# CONVENIENCE MARKET WITHOUT GAS                    1
# DAY CARE CENTER                                   2
# DORMITORY/BOARDING HOUSE                         19
# DUPLEX                                         1373
# FOREST                                           10
# GREENBELT                                        10
# GREENBELT/RES_x000D_\nGRRENBELT/RES               3
# LIGHT MANUFACTURING                               1
# METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK        1
# MOBILE HOME                                      20
# MORTUARY/CEMETERY                                 1
# NIGHTCLUB/LOUNGE                                  1
# NON-PROFIT CHARITABLE SERVICE                     2
# OFFICE BLDG (ONE OR TWO STORIES)                  2
# ONE STORY GENERAL RETAIL STORE                    1
# PARKING LOT                                      11
# PARSONAGE                                         6
# QUADPLEX                                         39
# RESIDENTIAL COMBO/MISC                           95
# RESIDENTIAL CONDO                             14080
# RESTURANT/CAFETERIA                               2
# SINGLE FAMILY                                 34197
# SMALL SERVICE SHOP                                1
# SPLIT CLASS                                      17
# STRIP SHOPPING CENTER                             1
# TERMINAL/DISTRIBUTION WAREHOUSE                   2
# TRIPLEX                                          92
# VACANT COMMERCIAL LAND                           17
# VACANT RES LAND                                1549
# VACANT RESIDENTIAL LAND                        3547
# VACANT RESIENTIAL LAND                            3
# VACANT RURAL LAND                                 2
# VACANT ZONED MULTI FAMILY                         2
# ZERO LOT LINE                                  1048
# Name: SalePrice, dtype: int64

# %% [markdown]
# We can see that the land was most used for Residential purposes

# %%
sns.scatterplot(x='LandUse', y='SalePrice', data=data);

# %% [markdown]
# 4. What is the average age of the properties?

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5f6c0fe114a3> in <module>()
# ----> 1 df= pd.DataFrame(YearBuilt)
#
# NameError: name 'YearBuilt' is not defined

# %%
c=data.groupby('YearBuilt').count()
c
# Out:
#            LandUse  PropertyAddress  SaleDate  SalePrice  Area  LandValue  \
# YearBuilt
# 1799.0           1                1         1          1     1          1
# 1832.0           1                1         1          1     1          1
# 1870.0           2                2         2          2     2          2
# 1880.0           1                1         1          1     1          1
# 1890.0           1                1         1          1     1          1
# ...            ...              ...       ...        ...   ...        ...
# 2013.0         297              297       297        297   297        297
# 2014.0         526              526       526        526   526        526
# 2015.0         712              707       712        712   712        712
# 2016.0         600              600       600        600   600        600
# 2017.0          13               13        13         13    13         13
#
#            BuildingValue  TotalValue  Bedrooms  FullWashroom  HalfWashroom  \
# YearBuilt
# 1799.0                 1           1         1             1             1
# 1832.0                 1           1         1             1             1
# 1870.0                 2           2         2             2             2
# 1880.0                 1           1         1             1             1
# 1890.0                 1           1         1             1             1
# ...                  ...         ...       ...           ...           ...
# 2013.0               297         297       297           297           297
# 2014.0               526         526       526           526           526
# 2015.0               712         712       712           712           712
# 2016.0               600         600       600           600           600
# 2017.0                13          13        13            13            13
#
#            Year  Month  Day
# YearBuilt
# 1799.0        1      1    1
# 1832.0        1      1    1
# 1870.0        2      2    2
# 1880.0        1      1    1
# 1890.0        1      1    1
# ...         ...    ...  ...
# 2013.0      297    297  297
# 2014.0      526    526  526
# 2015.0      712    712  712
# 2016.0      600    600  600
# 2017.0       13     13   13
#
# [127 rows x 14 columns]

# %%
df= pd.DataFrame(c)
df
# Out:
#            LandUse  PropertyAddress  SaleDate  SalePrice  Area  LandValue  \
# YearBuilt
# 1799.0           1                1         1          1     1          1
# 1832.0           1                1         1          1     1          1
# 1870.0           2                2         2          2     2          2
# 1880.0           1                1         1          1     1          1
# 1890.0           1                1         1          1     1          1
# ...            ...              ...       ...        ...   ...        ...
# 2013.0         297              297       297        297   297        297
# 2014.0         526              526       526        526   526        526
# 2015.0         712              707       712        712   712        712
# 2016.0         600              600       600        600   600        600
# 2017.0          13               13        13         13    13         13
#
#            BuildingValue  TotalValue  Bedrooms  FullWashroom  HalfWashroom  \
# YearBuilt
# 1799.0                 1           1         1             1             1
# 1832.0                 1           1         1             1             1
# 1870.0                 2           2         2             2             2
# 1880.0                 1           1         1             1             1
# 1890.0                 1           1         1             1             1
# ...                  ...         ...       ...           ...           ...
# 2013.0               297         297       297           297           297
# 2014.0               526         526       526           526           526
# 2015.0               712         712       712           712           712
# 2016.0               600         600       600           600           600
# 2017.0                13          13        13            13            13
#
#            Year  Month  Day
# YearBuilt
# 1799.0        1      1    1
# 1832.0        1      1    1
# 1870.0        2      2    2
# 1880.0        1      1    1
# 1890.0        1      1    1
# ...         ...    ...  ...
# 2013.0      297    297  297
# 2014.0      526    526  526
# 2015.0      712    712  712
# 2016.0      600    600  600
# 2017.0       13     13   13
#
# [127 rows x 14 columns]

# %% [markdown]
# 5. Have the age of houses affected the price?

# %%
d=data.groupby('YearBuilt')['SalePrice'].count()
d
# Out:
# YearBuilt
# 1799.0      1
# 1832.0      1
# 1870.0      2
# 1880.0      1
# 1890.0      1
#          ...
# 2013.0    297
# 2014.0    526
# 2015.0    712
# 2016.0    600
# 2017.0     13
# Name: SalePrice, Length: 127, dtype: int64

# %%
sns.jointplot(x=d.index, y=d.values)

# %% [markdown]
# 6. Have the number of rooms in the house affected the price?

# %%
data["TotalRooms"]=data['Bedrooms']+data['FullWashroom']+data['HalfWashroom']
data
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Area     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullWashroom  HalfWashroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day  TotalRooms
# UniqueID
# 2045       2013      4    9    6.000000
# 16918      2014      6   10    8.000000
# 54582      2016      9   26    7.000000
# 43070      2016      1   29    6.000000
# 22714      2014     10   10    7.000000
# ...         ...    ...  ...         ...
# 30469      2015      5   27    5.259848
# 27707      2015      3    2    5.259848
# 52709      2016      8   16    5.259848
# 54042      2016      9    7    5.259848
# 54043      2016      9    7    5.259848
#
# [56477 rows x 16 columns]

# %%
e=data.groupby('TotalRooms')['SalePrice'].count()
e
# Out:
# TotalRooms
# 0.000000        40
# 1.000000         2
# 2.000000        95
# 3.000000      3450
# 3.089912       118
# 3.283921         1
# 4.000000      4243
# 4.283921         7
# 5.000000      7366
# 5.169936         1
# 5.259848     32201
# 5.283921        46
# 6.000000      4545
# 6.283921        55
# 7.000000      1961
# 7.283921        18
# 8.000000      1102
# 8.089912         1
# 8.283921         4
# 9.000000       541
# 10.000000      304
# 11.000000      202
# 12.000000       94
# 13.000000       48
# 14.000000       19
# 15.000000        6
# 16.000000        2
# 17.000000        2
# 20.000000        2
# 22.000000        1
# Name: SalePrice, dtype: int64

# %%
sns.barplot(x=e.index,y=e.values)

# %%
sns.lineplot('TotalRooms','SalePrice',data=data);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 7. Does the size of the property (no. of acres) have any influence in its price?

# %%
f=data.groupby('Area')['SalePrice'].count()
f
# Out:
# Area
# 0.01       4
# 0.02       6
# 0.03       6
# 0.04      12
# 0.05      22
#           ..
# 47.50      1
# 51.34      1
# 62.96      1
# 68.79      1
# 160.06     1
# Name: SalePrice, Length: 520, dtype: int64

# %%
sns.lineplot('Area', 'SalePrice', data=data);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 8. Are houses located in specific pin numbers expensive over the others?

# %% [markdown]
# 9. How have house prices changed in the 21st centuary as supposed to 20th centuary.

# %%
g=data.groupby('Year')['BuildingValue'].count()
g
# Out:
# Year
# 2013    11292
# 2014    14283
# 2015    16829
# 2016    14071
# 2019        2
# Name: BuildingValue, dtype: int64

# %%
h=data.groupby('YearBuilt')['LandValue'].count()
h
# Out:
# YearBuilt
# 1799.0      1
# 1832.0      1
# 1870.0      2
# 1880.0      1
# 1890.0      1
#          ...
# 2013.0    297
# 2014.0    526
# 2015.0    712
# 2016.0    600
# 2017.0     13
# Name: LandValue, Length: 127, dtype: int64

# %%
cent=data[data["YearBuilt"]>=1900]
cent
# Out:
#                            LandUse                      PropertyAddress  \
# UniqueID
# 2045                 SINGLE FAMILY   1808  FOX CHASE DR, GOODLETTSVILLE
# 16918                SINGLE FAMILY   1832  FOX CHASE DR, GOODLETTSVILLE
# 54582                SINGLE FAMILY   1864 FOX CHASE  DR, GOODLETTSVILLE
# 43070                SINGLE FAMILY   1853  FOX CHASE DR, GOODLETTSVILLE
# 22714                SINGLE FAMILY   1829  FOX CHASE DR, GOODLETTSVILLE
# ...                            ...                                  ...
# 30469                SINGLE FAMILY  1435  WINDING CREEK DR, NOLENSVILLE
# 27707                SINGLE FAMILY  1423  WINDING CREEK DR, NOLENSVILLE
# 52709      VACANT RESIDENTIAL LAND    1804 GRACE POINT  LN, NOLENSVILLE
# 54042      VACANT RESIDENTIAL LAND   1709 PARK TERRACE  LN, NOLENSVILLE
# 54043      VACANT RESIDENTIAL LAND   1713 PARK TERRACE  LN, NOLENSVILLE
#
#             SaleDate  SalePrice      Area     LandValue  BuildingValue  \
# UniqueID
# 2045      2013-04-09     240000  2.300000  50000.000000  168200.000000
# 16918     2014-06-10     366000  3.500000  50000.000000  264100.000000
# 54582     2016-09-26     435000  2.900000  50000.000000  216200.000000
# 43070     2016-01-29     255000  2.600000  50000.000000  147300.000000
# 22714     2014-10-10     278000  2.000000  50000.000000  152300.000000
# ...              ...        ...       ...           ...            ...
# 30469     2015-05-27     157500  0.498923  69068.557601  160784.677109
# 27707     2015-03-02     145000  0.498923  69068.557601  160784.677109
# 52709     2016-08-16     234611  0.498923  69068.557601  160784.677109
# 54042     2016-09-07      93844  0.498923  69068.557601  160784.677109
# 54043     2016-09-07      93844  0.498923  69068.557601  160784.677109
#
#               TotalValue    YearBuilt  Bedrooms  FullWashroom  HalfWashroom  \
# UniqueID
# 2045       235700.000000  1986.000000  3.000000      3.000000      0.000000
# 16918      319000.000000  1998.000000  3.000000      3.000000      2.000000
# 54582      298000.000000  1987.000000  4.000000      3.000000      0.000000
# 43070      197300.000000  1985.000000  3.000000      3.000000      0.000000
# 22714      202300.000000  1984.000000  4.000000      3.000000      0.000000
# ...                  ...          ...       ...           ...           ...
# 30469      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 27707      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 52709      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54042      232375.398847  1963.744899  3.089912      1.886014      0.283921
# 54043      232375.398847  1963.744899  3.089912      1.886014      0.283921
#
#            Year  Month  Day  TotalRooms
# UniqueID
# 2045       2013      4    9    6.000000
# 16918      2014      6   10    8.000000
# 54582      2016      9   26    7.000000
# 43070      2016      1   29    6.000000
# 22714      2014     10   10    7.000000
# ...         ...    ...  ...         ...
# 30469      2015      5   27    5.259848
# 27707      2015      3    2    5.259848
# 52709      2016      8   16    5.259848
# 54042      2016      9    7    5.259848
# 54043      2016      9    7    5.259848
#
# [56376 rows x 16 columns]
